# %%
# %run ../talktools.py
# Out:
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width:800px;
#         margin-left:auto !important;
#         margin-right:auto;
# 		margin-top:1em;
# 		margin-bottom:1em;
#     }
#     h1 {
#         font-family: Helvetica, serif;
# 		background-color:#b0c4de;
#
#
#     }
# 	h2 {
#         font-family: Helvetica, serif;
# 		background-color:#b0c4de;
#
#
#     }
# 	h3 {
#         font-family: Helvetica, serif;
# 		background-color:#b0c4de;
#
#     }
#     h4{
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
#     div.text_cell_render{
#         font-family: Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         font-size: 130%;
#         width:800px;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
# ...

# %% [markdown]
# Analisis de Datos
# =======
#
# En este modulo repetiremos el analisis realizado en la libreta anterior utilizando la libreria `pandas`. Primero cargamos la libreria:

# %%
import pandas as pd
# %matplotlib inline

# %% [markdown]
# Ya hemos usado esta libreria, en el [analisis de datos del estado del tiempo en Xalapa](). Ahora la usaremos para analizar los datos de vuelos a partir de las bases de datos del [proyecto OpenFlights](http://openflights.org/data.html).

# %% [markdown]
# ## Leyendo datos de vuelos
#
# Leer archivos de texto en format `.csv` usando pandas es muy sencillo:

# %%
help( pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# read_csv(filepath_or_buffer, sep=',', dialect=None, compression=None, doublequote=True, escapechar=None, quotechar='"', quoting=0, skipinitialspace=False, lineterminator=None, header='infer', index_col=None, names=None, prefix=None, skiprows=None, skipfooter=None, skip_footer=0, na_values=None, na_fvalues=None, true_values=None, false_values=None, delimiter=None, converters=None, dtype=None, usecols=None, engine=None, delim_whitespace=False, as_recarray=False, na_filter=True, compact_ints=False, use_unsigned=False, low_memory=True, buffer_lines=None, warn_bad_lines=True, error_bad_lines=True, keep_default_na=True, thousands=None, comment=None, decimal='.', parse_dates=False, keep_date_col=False, dayfirst=False, date_parser=None, memory_map=False, nrows=None, iterator=False, chunksize=None, verbose=False, encoding=None, squeeze=False, mangle_dupe_cols=True, tupleize_cols=False, infer_datetime_format=False)
# ...

# %%
aeropuertos = pd.read_csv('../airports.dat')
aeropuertos.head()
# Out:
#    1                      Goroka      Goroka.1  Papua New Guinea  GKA  AYGA  \
# 0  2                      Madang        Madang  Papua New Guinea  MAG  AYMD
# 1  3                 Mount Hagen   Mount Hagen  Papua New Guinea  HGU  AYMH
# 2  4                      Nadzab        Nadzab  Papua New Guinea  LAE  AYNZ
# 3  5  Port Moresby Jacksons Intl  Port Moresby  Papua New Guinea  POM  AYPY
# 4  6                  Wewak Intl         Wewak  Papua New Guinea  WWK  AYWK
#
#    -6.081689  145.391881  5282  10  U  Pacific/Port_Moresby
# 0  -5.207083  145.788700    20  10  U  Pacific/Port_Moresby
# 1  -5.826789  144.295861  5388  10  U  Pacific/Port_Moresby
# 2  -6.569828  146.726242   239  10  U  Pacific/Port_Moresby
# 3  -9.443383  147.220050   146  10  U  Pacific/Port_Moresby
# 4  -3.583828  143.669186    19  10  U  Pacific/Port_Moresby

# %% [markdown]
# Los renglones indizados por numeros es consistente; tenemos que arreglar los titulos de las columnas. Por ejemplo

# %%
aeropuertos = pd.read_csv('../airports.dat', header=None)
aeropuertos.head()
# Out:
#    0                           1             2                 3    4     5   \
# 0   1                      Goroka        Goroka  Papua New Guinea  GKA  AYGA
# 1   2                      Madang        Madang  Papua New Guinea  MAG  AYMD
# 2   3                 Mount Hagen   Mount Hagen  Papua New Guinea  HGU  AYMH
# 3   4                      Nadzab        Nadzab  Papua New Guinea  LAE  AYNZ
# 4   5  Port Moresby Jacksons Intl  Port Moresby  Papua New Guinea  POM  AYPY
#
#          6           7     8   9  10                    11
# 0 -6.081689  145.391881  5282  10  U  Pacific/Port_Moresby
# 1 -5.207083  145.788700    20  10  U  Pacific/Port_Moresby
# 2 -5.826789  144.295861  5388  10  U  Pacific/Port_Moresby
# 3 -6.569828  146.726242   239  10  U  Pacific/Port_Moresby
# 4 -9.443383  147.220050   146  10  U  Pacific/Port_Moresby

# %% [markdown]
# Podemos usar la informacion de la pagina de datos para especificar los nombres de cada columna. Esto puede hacerse especificando los nombres con el argumento `names` del metodo `read_csv` (ver la documentacion arriba):

# %%
encabezados = ('ID', 'Name','City','Country','IATA/FAA','ICAO','Latitude','Longitude','Altitude','Timezone','DST','Tz database time zone')
aeropuertos = pd.read_csv('../airports.dat', names = encabezados)
aeropuertos.head()
# Out:
#    ID                        Name          City           Country IATA/FAA  \
# 0   1                      Goroka        Goroka  Papua New Guinea      GKA
# 1   2                      Madang        Madang  Papua New Guinea      MAG
# 2   3                 Mount Hagen   Mount Hagen  Papua New Guinea      HGU
# 3   4                      Nadzab        Nadzab  Papua New Guinea      LAE
# 4   5  Port Moresby Jacksons Intl  Port Moresby  Papua New Guinea      POM
#
#    ICAO  Latitude   Longitude  Altitude  Timezone DST Tz database time zone
# 0  AYGA -6.081689  145.391881      5282        10   U  Pacific/Port_Moresby
# 1  AYMD -5.207083  145.788700        20        10   U  Pacific/Port_Moresby
# 2  AYMH -5.826789  144.295861      5388        10   U  Pacific/Port_Moresby
# 3  AYNZ -6.569828  146.726242       239        10   U  Pacific/Port_Moresby
# 4  AYPY -9.443383  147.220050       146        10   U  Pacific/Port_Moresby

# %%
aeropuertos.dtypes
# Out:
# ID                         int64
# Name                      object
# City                      object
# Country                   object
# IATA/FAA                  object
# ICAO                      object
# Latitude                 float64
# Longitude                float64
# Altitude                   int64
# Timezone                 float64
# DST                       object
# Tz database time zone     object
# dtype: object

# %%
aeropuertos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8107 entries, 0 to 8106
# Data columns (total 12 columns):
# ID                       8107 non-null int64
# Name                     8107 non-null object
# City                     8107 non-null object
# Country                  8107 non-null object
# IATA/FAA                 5880 non-null object
# ICAO                     8043 non-null object
# Latitude                 8107 non-null float64
# Longitude                8107 non-null float64
# Altitude                 8107 non-null int64
# Timezone                 8107 non-null float64
# DST                      8107 non-null object
# Tz database time zone    8107 non-null object
# dtypes: float64(3), int64(2), object(7)

# %% [markdown]
# Comparemos con el metodo usado para leer los datos en la libreta anterior:

# %%
import csv
latitudes = {}
f = open("../airports.dat")
for renglon in csv.reader(f):
    airport_id = renglon[0]
    airport_name = renglon[1]
    latitudes[airport_id] = float(renglon[6])

# %% [markdown]
# Anteriormente leiamos el archivo linea por linea y debiamos asignar los valores leidos a una variable. Usando los metodos de `pandas` podemos leer todo el archivo en una sola instruccion y tener acceso a cada columna (y renglon) rapidamente. Por ejemplo comparemos la columna de latitudes del `Data Frame` con el diccionario creado:

# %%
aeropuertos.Latitude
# Out:
# 0     -6.081689
# 1     -5.207083
# 2     -5.826789
# 3     -6.569828
# 4     -9.443383
# 5     -3.583828
# 6     61.160517
# 7     64.190922
# 8     67.016969
# 9     76.531203
# 10    65.659994
# 11    65.283333
# 12    64.295556
# 13    65.952328
# 14    66.058056
# ...
# 8092    13.361002
# 8093    10.607220
# 8094    10.614922
# 8095    10.480174
# 8096    25.046176
# 8097   -29.716667
# 8098    34.256944
# 8099    36.136000
# 8100    48.850000
# 8101    49.616667
# 8102    50.066667
# 8103    50.575556
# 8104    50.883333
# 8105    48.618397
# 8106    32.755200
# Name: Latitude, Length: 8107, dtype: float64

# %%
latitudes
# Out:
# {'1': -6.081689,
#  '10': 76.531203,
#  '100': 45.3225,
#  '1000': 17.917053,
#  '1001': -20.017431,
#  '1002': -17.751561,
#  '1003': -21.008083,
#  '1004': -18.095881,
#  '1005': -17.931806,
#  '1006': -16.519761,
#  '1007': -17.431917,
#  '1008': -18.997499,
#  '1009': -20.055333,
#  '101': 53.214167,
#  '1010': -20.289497,
#  '1011': -19.436394,
#  '1012': -18.629872,
#  '1013': -15.679053,
#  '1014': -9.953569,
#  '1015': -13.014631,
#  '1016': -13.789378,
#  '1017': -11.44475,
#  '1018': -29.462256,
#  '1019': -29.304053,
#  '102': 56.226944,
#  '1020': -4.38575,
#  '1021': -4.326689,
#  '1022': -5.930858,
#  '1023': -5.918056,
#  '1024': -3.311319,
#  '1025': -5.035767,
#  '1026': 0.0226,
#  '1027': 4.253206,
#  '1028': 3.235369,
#  '1029': 4.157639,
#  '103': 49.903056,
#  '1030': 2.170658,
#  '1031': 0.5175,
#  '1032': 2.827606,
#  '1033': 1.565719,
#  '1034': 2.818347,
#  '1035': -2.308978,
#  '1036': -1.670814,
#  '1037': -2.919178,
#  '1038': -11.591333,
# ...

# %% [markdown]
# Imprimir los nombres de los aeropuertos en Mexico es tan sencillo que lo podemos hacer en una sola e intuitiva instruccion:

# %%
aeropuertos.Name[aeropuertos.Country=='Mexico']
# Out:
# 1749           General Juan N Alvarez Intl
# 1750                        Del Norte Intl
# 1751                      Jesus Teran Intl
# 1752               Bahias De Huatulco Intl
# 1753             General Mariano Matamoros
# 1754                 Ciudad Acuna Intl New
# 1755                Ciudad Del Carmen Intl
# 1756                   Nuevo Casas Grandes
# 1757                          Chilpancingo
# 1758                         Culiacan Intl
# 1759                         Chetumal Intl
# 1760                   Ciudad Obregon Intl
# 1761    Ingeniero Alberto Acuna Ongay Intl
# 1762                 Abraham Gonzalez Intl
# 1763      General R Fierro Villalobos Intl
# ...
# 4487    Captain Rogelio Castillo National Airport
# 5853                  Campo Cuatro Milpas Airport
# 5854                       Isla de Cedros Airport
# 5855         Cabo San Lucas International Airport
# 5856                      Bahia Tortugas Airfield
# 5857                           Palo Verde Airport
# ...

# %% [markdown]
# ## Ejercicio
#
# Encuentren los nombres de los aeropuertos de un pais de su eleccion y escriban tambien sus coordenadas geograficas.

# %%
## Escriban y ejecuten el codigo en esta celda

# %% [markdown]
# # Histograma de las Rutas de Aerolinea
#
# ## Ejercicio
#
# Leer el archivo de rutas de vuelos usando la libreria `pandas`, nombrando los encabezados correctamente de acuerdo al sitio del [proyecto OpenFlights](http://openflights.org/data.html).

# %%
## Escriban y ejecuten el codigo en esta celda

# %%
# Solucion
encabezados = ('Airline','Airline ID','Source airport','Source airport ID','Destination airport','Destination airport ID','Codeshare','Stops','Equipment')
rutas =  pd.read_csv('../routes.dat', names = encabezados)
rutas[:8]
# Out:
#   Airline Airline ID Source airport Source airport ID Destination airport  \
# 0      2B        410            AER              2965                 KZN
# 1      2B        410            ASF              2966                 KZN
# 2      2B        410            ASF              2966                 MRV
# 3      2B        410            CEK              2968                 KZN
# 4      2B        410            CEK              2968                 OVB
# 5      2B        410            DME              4029                 KZN
# 6      2B        410            DME              4029                 NBC
# 7      2B        410            DME              4029                 TGK
#
#   Destination airport ID Codeshare  Stops Equipment
# 0                   2990       NaN      0       CR2
# 1                   2990       NaN      0       CR2
# 2                   2962       NaN      0       CR2
# 3                   2990       NaN      0       CR2
# ...

# %% [markdown]
# Nuevamente, Usaremos las dos fuentes de datos para calcular que tan separadas estan cada una de las rutas de cada aerolinea, y crearemos un histograma mostrando la distribucion de las distancias de vuelo.

# %% [markdown]
# Veamos nuevamente los datos de aeropuertos que usaremos:

# %%
# Solo necesitamos una porcion de los datos
# aeropuertos=  pd.read_csv('../airports.dat', header=None)
ap_data = aeropuertos[[0,6,7]]
ap_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8107 entries, 0 to 8106
# Data columns (total 3 columns):
# ID           8107 non-null int64
# Latitude     8107 non-null float64
# Longitude    8107 non-null float64
# dtypes: float64(2), int64(1)

# %% [markdown]
# Ahora veamos los datos de rutas:

# %%
# Solo necesitamos una porcion de los datos
# rutas =  pd.read_csv('../routes.dat', header=None)
rt_data = rutas[[3,5]]
rt_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67663 entries, 0 to 67662
# Data columns (total 2 columns):
# Source airport ID         67663 non-null object
# Destination airport ID    67663 non-null object
# dtypes: object(2)

# %% [markdown]
# Ven las diferencias?
# Tratemos de convertir las columnas de rutas en enteros (representan IDs de aeropuertos):

# %%
rt_data[:8]
# Out:
#   Source airport ID Destination airport ID
# 0              2965                   2990
# 1              2966                   2990
# 2              2966                   2962
# 3              2968                   2990
# 4              2968                   4078
# 5              4029                   2990
# 6              4029                   6969
# 7              4029                     \N

# %% [markdown]
# Pueden ver que hay algunos elementos "sucios"? El metodo `pd.isnull` de pandas puede usarse en algunos casos pues contiene una lista de valores considerados como nulos. En este caso no servira porque `\\N` no se considera un elemento nulo.

# %%
pd.isnull(rt_data[:8])
# Out:
#   Source airport ID Destination airport ID
# 0             False                  False
# 1             False                  False
# 2             False                  False
# 3             False                  False
# 4             False                  False
# 5             False                  False
# 6             False                  False
# 7             False                  False

# %%
rt_data[rt_data == '\\N'] = np.nan

# %%
rt_data[:8]
# Out:
#   Source airport ID Destination airport ID
# 0              2965                   2990
# 1              2966                   2990
# 2              2966                   2962
# 3              2968                   2990
# 4              2968                   4078
# 5              4029                   2990
# 6              4029                   6969
# 7              4029                    NaN

# %%
rt_data_clean = rt_data.dropna()

# %%
rt_data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67202 entries, 0 to 67662
# Data columns (total 2 columns):
# Source airport ID         67202 non-null object
# Destination airport ID    67202 non-null object
# dtypes: object(2)

# %%
rt_data_clean = rt_data_clean.astype(int)

# %%
rt_data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67202 entries, 0 to 67662
# Data columns (total 2 columns):
# Source airport ID         67202 non-null int64
# Destination airport ID    67202 non-null int64
# dtypes: int64(2)

# %%
ap_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8107 entries, 0 to 8106
# Data columns (total 3 columns):
# ID           8107 non-null int64
# Latitude     8107 non-null float64
# Longitude    8107 non-null float64
# dtypes: float64(2), int64(1)

# %% [markdown]
# ## Obteniendo coordenadas de aeropuertos de salida
# Ahora que tenemos los datos limpios podemos obtener las coordenadas geograficas de aquellos aeropuertos de salida de la base de datos de rutas

# %%
ap_data[ap_data['ID'] == rt_data_clean['Source airport ID'][0]]
# Out:
#         ID   Latitude  Longitude
# 2886  2965  43.449928  39.956589

# %%
ap_data_clean = ap_data.set_index('ID')

# %%
ap_data.head()
# Out:
#    ID  Latitude   Longitude
# 0   1 -6.081689  145.391881
# 1   2 -5.207083  145.788700
# 2   3 -5.826789  144.295861
# 3   4 -6.569828  146.726242
# 4   5 -9.443383  147.220050

# %%
ap_data_clean.head()
# Out:
#     Latitude   Longitude
# ID
# 1  -6.081689  145.391881
# 2  -5.207083  145.788700
# 3  -5.826789  144.295861
# 4  -6.569828  146.726242
# 5  -9.443383  147.220050

# %%
rt_data_clean.head()
# Out:
#    Source airport ID  Destination airport ID
# 0               2965                    2990
# 1               2966                    2990
# 2               2966                    2962
# 3               2968                    2990
# 4               2968                    4078

# %%
sour = ap_data_clean.ix[rt_data_clean['Source airport ID']]
# ap_data_clean.loc[rt_data_clean['Source airport ID']]
sour.head()
# Out:
#        Latitude  Longitude
# ID
# 2965  43.449928  39.956589
# 2966  46.283333  48.006278
# 2966  46.283333  48.006278
# 2968  55.305836  61.503333
# 2968  55.305836  61.503333

# %%
dest = ap_data_clean.ix[rt_data_clean['Destination airport ID']]
dest.head()
# Out:
#        Latitude  Longitude
# ID
# 2990  55.606186  49.278728
# 2990  55.606186  49.278728
# 2962  44.225072  43.081889
# 2990  55.606186  49.278728
# 4078  55.012622  82.650656

# %%
rt_data_clean.loc[0]
# Out:
# Source airport ID         2965
# Destination airport ID    2990
# Name: 0, dtype: int64

# %%
rt_data_clean.loc[0]['Source airport ID']
# Out:
# 2965

# %%
latitudes_source_airports = ap_data_clean['Latitude'].ix[rt_data_clean['Source airport ID']]
latitudes_dest_airports = ap_data_clean['Latitude'].ix[rt_data_clean['Destination airport ID']]

# %%
longitudes_source_airports = ap_data_clean['Longitude'].ix[rt_data_clean['Source airport ID']]
longitudes_dest_airports = ap_data_clean['Longitude'].ix[rt_data_clean['Destination airport ID']]

# %%
source_lat = np.array(latitudes_source_airports)
source_long = np.array(longitudes_source_airports)

dest_lat = np.array(latitudes_dest_airports)
dest_long = np.array(longitudes_dest_airports)

# %%
distancias = distance(source_lat,source_long,dest_lat,dest_long)

# %%
dist = pd.Series(distancias)

# %%
dist.hist(bins=100)

# %%
plt.hist(distancias, 100, facecolor='r');

# %% [markdown]
# ## Ejercicio
# Obtengan las coordenadas de aeropuertos de llegada

# %%
## Escriban y ejecuten el codigo en esta celda
cond = ap_data['ID'].isin(rt_data_clean['Destination airport ID'])
dest_latlon = ap_data[['Latitude', 'Longitude']][cond]
dest_latlon.head()
# Out:
#    Latitude   Longitude
# 0 -6.081689  145.391881
# 1 -5.207083  145.788700
# 2 -5.826789  144.295861
# 3 -6.569828  146.726242
# 4 -9.443383  147.220050

# %% [markdown]
# ## Calculando la distancia entre rutas
# ahora podemos aplicar la funcion que calcula la distancia entre coordenadas geograficas:

# %%
load http://opentechschool.github.io/python-data-intro/files/geo_distance.py

# %%
source_latlon.head()
# Out:
#    Latitude   Longitude
# 0 -6.081689  145.391881
# 1 -5.207083  145.788700
# 2 -5.826789  144.295861
# 3 -6.569828  146.726242
# 4 -9.443383  147.220050

# %%
dest_latlon.head()
# Out:
#    Latitude   Longitude
# 0 -6.081689  145.391881
# 1 -5.207083  145.788700
# 2 -5.826789  144.295861
# 3 -6.569828  146.726242
# 4 -9.443383  147.220050

# %%
rt_data.head()
# Out:
#   Source airport ID Destination airport ID
# 0              2965                   2990
# 1              2966                   2990
# 2              2966                   2962
# 3              2968                   2990
# 4              2968                   4078

# %%
ap_data.dtypes
# Out:
# ID             int64
# Latitude     float64
# Longitude    float64
# dtype: object

# %% [markdown]
# ## Este es un excelente problema
# para que en equipos o grupos lo resuelvan, asi cada grupo puede proponer una solucion diferente!
#
# * Primero se asegura que el grupo entienda cual es el problema
# * Brainstorming para buscar soluciones
#     * Que necesita para resolverlo -
#     * Como lo va a resolver - separar en partes para obtner cada una de las partes que necesita

# %% [markdown]
# # Una posible solucion se presenta
#
# Este problema consiste de varias partes:
#
# * Leer el archivo de aeropuertos `airports.dat` y crear un diccionario que relacione el identificador unico de cada aeropuerto (ID) con sus coordenadas geograficas (latitud y longitud). De esta manera podemos encontrar la localizacion de cada aeropuerto por medio de su identificador (ID).
#
# * Leer el archivo con las rutas `routes.dat` y obtener las IDs de los aeropuertos de salida y de destino. Buscar las coordenadas geograficas con base en la ID. Usando estas coordenadas, calcular la longitud de la ruta y agregarla a una lista de loingitudes de las rutas.
#
# * Graficar un histograma a partir de las longitudes para ver la distribucion de distancias de vuelo.
#
# ## Solucion
#
#     distances = []
#     f = open("routes.dat")
#     for row in csv.reader(f):
#         source_airport = row[3]
#         dest_airport = row[5]
#         if source_airport in latitudes and dest_airport in latitudes:
#             source_lat = latitudes[source_airport]
#             source_long = longitudes[source_airport]
#             dest_lat = latitudes[dest_airport]
#             dest_long = longitudes[dest_airport]
#             distances.append(geo_distance.distance(source_lat,source_long,dest_lat,dest_long))
#
# **TIP:** You might come across an error like "KeyError: \\N" when you first run your program. This is another problem of 'dirty data', the "routes.dat" file contains some airports that aren't listed in "airports.dat". You can skip these routes by adding a test of the type `if airport in latitudes`. If you don't quite get what I mean, sneak a peek at the solution to see one way this could work.

# %%
rutas.head()
# Out:
#   Airline Airline ID Source airport Source airport ID Destination airport  \
# 0      2B        410            AER              2965                 KZN
# 1      2B        410            ASF              2966                 KZN
# 2      2B        410            ASF              2966                 MRV
# 3      2B        410            CEK              2968                 KZN
# 4      2B        410            CEK              2968                 OVB
#
#   Destination airport ID Codeshare  Stops Equipment
# 0                   2990       NaN      0       CR2
# 1                   2990       NaN      0       CR2
# 2                   2962       NaN      0       CR2
# 3                   2990       NaN      0       CR2
# 4                   4078       NaN      0       CR2

# %%
rutas['Source airport ID']
# Out:
# 0     2965
# 1     2966
# 2     2966
# 3     2968
# 4     2968
# 5     4029
# 6     4029
# 7     4029
# 8     4029
# 9     6156
# 10    6156
# 11    2922
# 12    2952
# 13    2990
# 14    2990
# ...
# 67648    3361
# 67649    3361
# 67650    6794
# 67651    6794
# 67652    3330
# 67653    3330
# 67654    3363
# 67655    3363
# 67656    6337
# 67657    6337
# 67658    6334
# 67659    4029
# 67660    2912
# 67661    2912
# 67662    2913
# Name: Source airport ID, Length: 67663, dtype: object

# %%
aeropuertos.ID == rutas['Source airport ID']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-4207bfd4432f> in <module>()
# ----> 1 aeropuertos.ID == rutas['Source airport ID']
#
# /usr/lib/python2.7/dist-packages/pandas/core/ops.pyc in wrapper(self, other)
#     549             name = _maybe_match_name(self, other)
#     550             if len(self) != len(other):
# --> 551                 raise ValueError('Series lengths must match to compare')
#     552             return self._constructor(na_op(self.values, other.values),
#     553                                      index=self.index, name=name)
#
# ValueError: Series lengths must match to compare

# %% [markdown]
# ## Histogram
#
# La lista de distancias entre rutas que se guarda en la lista `distances` puede usarse para crear un histograma:
#
#     import numpy as np
#     import matplotlib.pyplot as plt
#     %matplotlib inline
#
#     plt.hist(distances, 100, facecolor='r')
#     plt.xlabel("Distance (km)")
#     plt.ylabel("Number of flights")

# %% [markdown]
# # Listo!
#
# Hemos usado datos del mundo real para graficarlos de una manera informativa! Es verdad que no son los resultados mas impactantes pero nos llevan en la direccion correcta para entender algunas tecnicas que se llevan a cabo en el analisis de datos.
#
# En el siguiente modulo volveremos a este ejemplo pero usando la libreria `pandas`. Por ahora, felicidades! y no olviden guardar los cambios a sus documentos.
