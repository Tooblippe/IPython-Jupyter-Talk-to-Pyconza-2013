# %% [markdown]
# # Dia 2 Libreta 6
# En esta libreta usaremos un clasificador para detectar rostros en imagenes; despues realizaran el ejercicio de tomar una foto de su rostro con el dispositivo, extraerlo del mismo a la mnaquina y aplciar el detector.
#
# Finalmente, trataremos de implementarlo en el dispositivo...
#
# Algo de informacion [tomada de este sitio](https://realpython.com/blog/python/face-recognition-with-python/)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import sys, os, re, time
import numpy as np
import cv2

# %%
pic = os.path.join('.','carota.jpg')#ZuzanaB.jpg')

# %%
img=cv2.imread(pic)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)

# %%
caras_cascada=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
caras = caras_cascada.detectMultiScale(gray, 1.2, 2)

# %%
print "Encontramos {0} faces!".format(len(caras))
# Out:
# Encontramos 0 faces!

# %%
for (x,y,w,h) in caras:
    cv2.rectangle(img, (x,y), (x+w,y+h), (0,255,0), 2)

# %%
plt.imshow(img)

# %%
import android
droide=android.Android()

# %%
droide.ttsSpeak("Hola listo para el registro")
# Out:
# Result(id=0, result=None, error=None)

# %%
droide.cameraCapturePicture('/sdcard/DCIM/CAMERA/carota.jpg')
# Out:
# Result(id=4, result={u'takePicture': True, u'autoFocus': False, u'cameraId': 0}, error=None)

# %%
# !adb pull /sdcard/DCIM/carota.jpg
# Out:
# 2273 KB/s (60541 bytes in 0.026s)

# %%
droide.getLaunchableApplications().result
# Out:
# {u'Adblock Plus': u'org.adblockplus.android.Preferences',
#  u'Barcode Scanner': u'com.google.zxing.client.android.H5View',
#  u'Brain Challenge 4: Breaking Limits': u'com.gameloft.android.LATAM.B329.Start',
#  u'Calculator': u'com.sec.android.app.popupcalculator.Calculator',
#  u'Camera': u'com.sec.android.app.camera.Camera',
#  u'Chrome': u'com.google.android.apps.chrome.Main',
#  u'ClaroVideo': u'com.clarovideo.app.ui.activities.SplashActivity',
#  u'Clarojuegos': u'com.gameloft.android.gdc.GDCMainShop',
#  u'Clarom\xfasica': u'com.telcel.imk.MainActivity',
#  u'Clock': u'com.sec.android.app.clockpackage.ClockPackage',
#  u'Contacts': u'com.android.contacts.activities.PeopleActivity',
#  u'Downloads': u'com.android.providers.downloads.ui.DownloadList',
#  u'Drive': u'com.google.android.apps.docs.app.NewMainProxyActivity',
#  u'Email': u'com.android.email.activity.Welcome',
#  u'Flashlight': u'com.devuni.flashlight.MainActivity',
#  u'Flipboard': u'flipboard.activities.LaunchActivityAlias',
#  u'GPS Telcel': u'com.telenav.app.android.gpstelcel.TeleNav',
#  u'GPS Tracks Uploader': u'com.whitedavidp.mytracksuploader.MainActivity',
#  u'Galaxy Apps': u'com.sec.android.app.samsungapps.SamsungAppsMainActivity',
#  u'Gallery': u'com.sec.android.gallery3d.app.Gallery',
#  u'Gmail': u'com.google.android.gm.ConversationListActivityGmail',
#  u'Google': u'com.google.android.googlequicksearchbox.SearchActivity',
#  u'Google Settings': u'com.google.android.gms.app.settings.GoogleSettingsActivity',
#  u'Google+': u'com.google.android.apps.plus.phone.HomeActivity',
#  u'Group Play': u'com.samsung.groupcast.start.StartActivity',
#  u'Hangouts': u'com.google.android.talk.SigningInActivity',
#  u'Help': u'com.samsung.helphub.HelpHubActivity',
#  u'IUSACELL 4G': u'com.android.stk.StkLauncherActivity',
#  u'Internet': u'com.sec.android.app.sbrowser.SBrowserMainActivity',
#  u'MW Sampler': u'com.olympiapps.mwsampler.Main',
#  u'Map My Tracks': u'com.mapmytracks.outfrontfree.view.dashboard.Dashboard',
#  u'Maps': u'com.google.android.maps.MapsActivity',
#  u'Messages': u'com.android.mms.ui.ConversationComposer',
#  u'Mi Telcel': u'com.speedymovil.wire.Login',
#  u'Mobizen for SAMSUNG': u'com.rsupport.mvagent.ui.activity.splash.SplashActivity',
#  u'Music': u'com.sec.android.app.music.MusicActionTabActivity',
#  u'My Files': u'com.sec.android.app.myfiles.MainActivity',
#  u'My Sensors': u'com.kfodor.MySensors.MySensors',
#  u'My Tracks': u'com.google.android.apps.mytracks.TrackListActivity',
#  u'Phone': u'com.android.contacts.activities.DialtactsActivity',
#  u'Photos': u'com.google.android.apps.plus.phone.ConversationListActivity',
#  u'Play Books': u'com.google.android.apps.books.app.BooksActivity',
#  u'Play Games': u'com.google.android.gms.games.ui.destination.main.MainActivity',
#  u'Play Movies & TV': u'com.google.android.youtube.videos.EntryPoint',
#  u'Play Music': u'com.android.music.activitymanagement.TopLevelActivity',
#  u'Play Store': u'com.android.vending.AssetBrowserActivity',
#  u'Portal Claroideas': u'com.portal.Portal',
#  u'Python for Android': u'com.googlecode.pythonforandroid.PythonMain',
#  u'QR Code Reader': u'me.scan.android.client.ui.ScanActivity',
#  u'Qr Barcode Scanner': u'com.QRBS.activity.StartActivity',
#  u'RF Signal Tracker': u'com.hotrod.utility.rfsignaltrackereclair.RFTabHost',
#  u'RF Signal Tracker (Donut)': u'com.hotrod.utility.rfsignaltracker.RFController',
#  u'Radio': u'com.sec.android.app.fm.MainActivity',
#  u'RegionLock Away': u'eu.chainfire.regionlockaway.MainActivity',
#  u'Root Check': u'com.jrummyapps.rootchecker.ui.activities.RootCheckerActivity',
#  u'S Memo': u'com.sec.android.widgetapp.q1_penmemo.MemoListActivity',
#  u'S Planner': u'com.android.calendar.AllInOneActivity',
#  u'S Translator': u'com.sec.android.app.translator.MainActivity',
#  u'S Voice': u'com.vlingo.midas.gui.ConversationActivity',
#  u'SL4A': u'com.googlecode.android_scripting.activity.ScriptManager',
#  u'Samsung Hub': u'com.sec.everglades.main.HomeActivity',
#  u'Samsung Link': u'com.mfluent.asp.ui.MobileChargesNotificationActivity',
#  u'Samsung TV remote': u'ir.remote.smg.tv.MainActivity',
#  u'Settings': u'com.android.settings.Settings',
#  u'Shell Terminal Emulator': u'com.acr.shellterminalemulator.Main',
#  u'Story Album': u'com.samsung.android.app.episodes.ui.timeline.TimelineActivity',
#  u'SuperSU': u'eu.chainfire.supersu.MainActivity-Emblem',
#  u'SwiftKey Keyboard': u'com.touchtype.LauncherActivity',
#  u'Tasker': u'net.dinglisch.android.taskerm.Tasker',
#  u'Telcel': u'com.telcel.contenedor.gui.activities.AppsContainerActivity',
#  u'TripAdvisor': u'com.tripadvisor.tripadvisor.TripAdvisorTripAdvisorActivity',
#  u'UNO': u'com.gameloft.android.LATAM.B330.Start',
#  u'UnoTelly': u'com.app.unotelly.MainActivity',
#  u'Video': u'com.samsung.everglades.video.VideoMain',
#  u'Voice Recorder': u'com.sec.android.app.voicerecorder.VoiceRecorderMainActivity',
#  u'Voice Search': u'com.google.android.googlequicksearchbox.VoiceSearchActivity',
#  u'Waze': u'com.waze.FreeMapAppActivity',
#  u'YouTube': u'com.google.android.youtube.app.honeycomb.Shell$HomeActivity'}
