# %% [markdown]
# En esta sesion tomaremos datos en forma de imagenes digitales usando nuestros dispositivos moviles.

# %% [markdown]
# Haremos honor al metodo desarrollado por [Antoine van Leeuwenhoek](http://es.wikipedia.org/wiki/Anton_van_Leeuwenhoek) en los 1600s.

# %%
from IPython.display import HTML
HTML(url='http://es.wikipedia.org/wiki/Anton_van_Leeuwenhoek')
# Out:
# <!DOCTYPE html>
# <html lang="es" dir="ltr" class="client-nojs">
# <head>
# <meta charset="UTF-8" />
# <title>Anton van Leeuwenhoek - Wikipedia, la enciclopedia libre</title>
# <meta name="generator" content="MediaWiki 1.24wmf22" />
# <link rel="alternate" href="android-app://org.wikipedia/http/es.m.wikipedia.org/wiki/Anton_van_Leeuwenhoek" />
# <link rel="alternate" type="application/x-wiki" title="Editar" href="/w/index.php?title=Anton_van_Leeuwenhoek&amp;action=edit" />
# <link rel="edit" title="Editar" href="/w/index.php?title=Anton_van_Leeuwenhoek&amp;action=edit" />
# <link rel="apple-touch-icon" href="//bits.wikimedia.org/apple-touch/wikipedia.png" />
# <link rel="shortcut icon" href="//bits.wikimedia.org/favicon/wikipedia.ico" />
# <link rel="search" type="application/opensearchdescription+xml" href="/w/opensearch_desc.php" title="Wikipedia (es)" />
# <link rel="EditURI" type="application/rsd+xml" href="//es.wikipedia.org/w/api.php?action=rsd" />
# ...

# %% [markdown]
# Se dice que van Leeuwenhoek realizo algunas de sus primeras observaciones microscopicas usando una gota de agua.

# %%
from IPython.display import Image
Image(url='http://1.bp.blogspot.com/-K16-1qulgJY/UtU-BXagDxI/AAAAAAAAAKY/1w2qspa5fgs/s1600/Olaf+telescope.jpg')
# Out:
# <img src="http://1.bp.blogspot.com/-K16-1qulgJY/UtU-BXagDxI/AAAAAAAAAKY/1w2qspa5fgs/s1600/Olaf+telescope.jpg"/>
