# %%
# %run ../talktools.py
# Out:
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width:800px;
#         margin-left:auto !important;
#         margin-right:auto;
# 		margin-top:1em;
# 		margin-bottom:1em;
#     }
#     h1 {
#         font-family: Helvetica, serif;
# 		background-color:#b0c4de;
#
#
#     }
# 	h2 {
#         font-family: Helvetica, serif;
# 		background-color:#b0c4de;
#
#
#     }
# 	h3 {
#         font-family: Helvetica, serif;
# 		background-color:#b0c4de;
#
#     }
#     h4{
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
#     div.text_cell_render{
#         font-family: Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         font-size: 130%;
#         width:800px;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
#             font-family: "Source Code Pro", source-code-pro,Consolas, monospace;
#     }
#
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 22pt;
#         color: #4057A1;
#         font-style: italic;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#
#     .warning{
#         color: rgb( 240, 20, 20 )
#         }
#
# 		div.cell.code_cell {  /* Areat containing both code and output */
# 		background-color:#F1F0FF; /* light blue */
# 		border-radius: 10px; /* rounded borders = friendlier */
# 		padding: 1em;
# 		}
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %% [markdown]
# # IPython Notebook
#
# ![IPython Notebook](http://ipython.org/_static/ipy_0.13.png)

# %% [markdown]
# ## Graficando con Matplotlib
# `matplotlib` es una libreria para hacer graficas en 2D que produce figuras de calidad en diversos formatos. Tambien puede usarse en un ambiente interactivo a traves de distintas plataformas. `matplotlib` puede usarse en scripts de python, en el interprete de python, en las libretas, en aplicaciones web y en por lo menos 6 interfaces graficas.

# %% [markdown]
# Para poder desplegar las graficas creadas con `matplotlib` en una libreta conviene ejecutar la siguiente funcion magica antes de evaluar funciones de esta libreria:
#
#         %matplotlib inline
#
# En caso contrario, las graficas **no** seran desplegadas o dependiendo del "frontend" configurado, se abrira una nueva ventan con la grafica.

# %%
# %matplotlib inline

# %%
CustomPlot()
num_alumnos = 20
r = 2*np.random.random(num_alumnos)
theta = 2*np.pi*np.random.rand(num_alumnos)
area = 200*r**2*np.random.random(num_alumnos)

ax = plt.subplot(111,polar=True)
c = plt.scatter(theta, r,c=theta,s=area,alpha=.75)

# %%
# CustomPlot()
font_size = 20
figsize(11.5, 6)

t = np.arange(0.0, 2.0, 0.01)
s = np.sin(2*np.pi*t)
plt.plot(t, s)

plt.xlabel(r'tiempo $(s)$', fontsize=font_size)
plt.ylabel('voltaje $(mV)$', fontsize=font_size)
plt.title('Voltaje', fontsize=font_size)
plt.grid(True)

# %%
# CustomPlot()

#generate some data
n = np.array([0,1,2,3,4,5])
xx = np.linspace(-0.75, 1., 100)
x = np.linspace(0, 5, 10)
y = x ** 2

fig, axes = plt.subplots(1, 4, figsize=(12,3))

axes[0].scatter(xx, xx + 0.25*np.random.randn(len(xx)))
axes[0].set_title('scatter')
axes[1].step(n, n**2, lw=2)
axes[1].set_title('step')
axes[2].bar(n, n**2, align="center", width=0.5, alpha=0.5)
axes[2].set_title('bar')
axes[3].fill_between(x, x**2, x**3, color="green", alpha=0.5);
axes[3].set_title('fill')

for i in range(4):
    axes[i].set_xlabel('x')
axes[0].set_ylabel('y')

# %% [markdown]
# ## Combinando graficas

# %%
# CustomPlot()
font_size = 20
figsize(11.5, 6) 
fig, ax = plt.subplots()

ax.plot(xx, xx**2, xx, xx**3)
ax.set_title(r"Combined Plot $y=x^2$ vs. $y=x^3$", fontsize = font_size)
ax.set_xlabel(r'$x$', fontsize = font_size)
ax.set_ylabel(r'$y$', fontsize = font_size)
fig.tight_layout()
# inset
inset_ax = fig.add_axes([0.29, 0.45, 0.35, 0.35]) # X, Y, width, height
inset_ax.plot(xx, xx**2, xx, xx**3)
inset_ax.set_title(r'zoom $x=0$',fontsize=font_size)
# set axis range
inset_ax.set_xlim(-.2, .2)
inset_ax.set_ylim(-.005, .01)
# set axis tick locations
inset_ax.set_yticks([0, 0.005, 0.01])
inset_ax.set_xticks([-0.1,0,.1]);

# %% [markdown]
# ## Agregando texto a una grafica

# %%
# CustomPlot()
figsize(11.5, 6) 
font_size = 20
fig, ax = plt.subplots()
ax.plot(xx, xx**2, xx, xx**3)
ax.set_xlabel(r'$x$', fontsize = font_size)
ax.set_ylabel(r'$y$', fontsize = font_size)
ax.set_title(r"Adding Text $y=x^2$ vs. $y=x^3$", fontsize = font_size)
ax.text(0.15, 0.2, r"$y=x^2$", fontsize=font_size, color="blue")
ax.text(0.65, 0.1, r"$y=x^3$", fontsize=font_size, color="green");

# %% [markdown]
# ## Ejercicio
#
# Vamos a utilizar `matplotlib` con frecuencia, ya que es la libreria estandar para hacer graficas en Python. Por ahora repitan el codigo de las celdas de esta libreta cambiando parametros y ejecuetenlos. No olviden guardar los cambios a la libreta.

# %% [markdown]
# A continuacion veremos [matematicas simbolicas.](Lib08_Esenciales_IPython_Notebook.ipynb)
